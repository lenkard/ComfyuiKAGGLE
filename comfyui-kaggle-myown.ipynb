# %% [markdown]
# # Installation

# %% [markdown]
# Session options:
#  * Accelerator: GPU T4 x2
#  * Language: Python
#  * Persistence: File Only
#  * Environment: Pin to original environment

# %%
# Set the base image
#ARG BASE_IMAGE
#FROM ${BASE_IMAGE}

# Set the shell and enable pipefail for better error handling
#SHELL ["/bin/bash", "-o", "pipefail", "-c"]

# Set basic environment variables
PYTHON_VERSION=3.12
TORCH_VERSION=2.7.0
CUDA_VERSION=12.6.3
#ENV PREINSTALLED_MODEL

# Set basic environment variables
SHELL=/bin/bash 
PYTHONUNBUFFERED=True 
#DEBIAN_FRONTEND=noninteractive
TZ=America/Sao_Paulo




# Install essential packages (optimized to run in one command)
# !apt-get update --yes 
# !apt-get upgrade --yes 
# !apt-get install --yes --no-install-recommends git wget curl bash nginx-light rsync sudo binutils ffmpeg lshw nano tzdata file build-essential nvtop libgl1 libglib2.0-0 clang libomp-dev ninja-build openssh-server ca-certificates
# !apt-get autoremove -y 
# !apt-get clean
# !rm -rf /var/lib/apt/lists/* /var/cache/apt/archives/*

# Install the UV tool from astral-sh
#ADD https://astral.sh/uv/install.sh /uv-installer.sh
#RUN sh /uv-installer.sh && rm /uv-installer.sh
#ENV PATH="/root/.local/bin/:$PATH"

# Install Python and create virtual environment
#RUN uv python install ${PYTHON_VERSION} --default --preview && \
#    uv venv --seed /venv
#ENV PATH="/workspace/venv/bin:/venv/bin:$PATH"
# !pip install uv

# Install essential Python packages and dependencies
RUN pip install --no-cache-dir -U \
    pip setuptools wheel \
    jupyterlab jupyterlab_widgets ipykernel ipywidgets \
    huggingface_hub hf_transfer \
    numpy scipy matplotlib pandas scikit-learn seaborn requests tqdm pillow pyyaml \
    triton \
    torch==${TORCH_VERSION} torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/${CUDA_VERSION}

# Install ComfyUI and ComfyUI Manager
RUN git clone https://github.com/comfyanonymous/ComfyUI.git && \
    cd ComfyUI && \
    pip install --no-cache-dir -r requirements.txt && \
    git clone https://github.com/ltdrdata/ComfyUI-Manager.git custom_nodes/ComfyUI-Manager && \
    cd custom_nodes/ComfyUI-Manager && \
    pip install --no-cache-dir -r requirements.txt

RUN cd /ComfyUI/custom_nodes && \
    git clone --recursive https://github.com/ssitu/ComfyUI_UltimateSDUpscale.git && \
    git clone --recursive https://github.com/receyuki/comfyui-prompt-reader-node.git && \
    git clone https://github.com/comfyanonymous/ComfyUI_TensorRT.git && \
    git clone https://github.com/cubiq/ComfyUI_essentials.git && \
    git clone https://github.com/ltdrdata/ComfyUI-Impact-Pack.git && \
    git clone https://github.com/ltdrdata/ComfyUI-Impact-Subpack.git && \
    git clone https://github.com/jags111/efficiency-nodes-comfyui.git && \
    git clone https://github.com/pythongosssss/ComfyUI-Custom-Scripts.git && \
    git clone https://github.com/JPS-GER/ComfyUI_JPS-Nodes.git && \
    git clone https://github.com/chrisgoringe/cg-use-everywhere.git && \
    git clone https://github.com/crystian/ComfyUI-Crystools.git && \
    git clone https://github.com/rgthree/rgthree-comfy.git && \
    git clone https://github.com/alexopus/ComfyUI-Image-Saver.git && \
    git clone https://github.com/kijai/ComfyUI-WanVideoWrapper.git && \
    git clone https://github.com/Kosinkadink/ComfyUI-VideoHelperSuite.git && \
    git clone https://github.com/city96/ComfyUI-GGUF.git && \
    git clone https://github.com/kijai/ComfyUI-KJNodes && \
    git clone https://github.com/Flow-two/ComfyUI-WanStartEndFramesNative.git && \
    git clone https://github.com/Smirnov75/ComfyUI-mxToolkit.git && \
    git clone https://github.com/Fannovel16/ComfyUI-Frame-Interpolation.git && \
    find /ComfyUI/custom_nodes -name "requirements.txt" -exec pip install --no-cache-dir -r {} \; && \
    find /ComfyUI/custom_nodes -name "install.py" -exec python {} \;

# %%
'''%%time
update = False

import os
import stat
#!rm -rf /kaggle/working/*
#!/usr/local/bin/python -m venv /kaggle/working/venv
home_dir = '/kaggle/working'
python = '/kaggle/working/venv/bin/python'
pip = '/kaggle/working/venv/bin/pip'

def find_bin_folders(folder_path):
    bin_folders = []
    for root, dirs, files in os.walk(folder_path):
        for dir_name in dirs:
            if dir_name == 'bin':
                bin_folders.append(os.path.join(root, dir_name)) 
    return bin_folders

def installLibraries(home_dir, python, pip):
  # %cd {home_dir}
  # !{pip} install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
  # !{pip} install tensorflow[and-cuda]
  #!wget https://q4j3.c11.e2-5.dev/downloads/req.txt
  # !{pip} install -r /kaggle/input/requirementforcomfyui/req.txt

# !pip install virtualenv

if not os.path.exists(f'{home_dir}/venv'):
    print('installing venv')
    os.chdir(home_dir)
    get_ipython().system(f'cd {home_dir}')
    
    get_ipython().system('virtualenv venv -p $(which python3.10)')
    installLibraries(home_dir, python, pip)
else:
    bin_folders = find_bin_folders('/kaggle/working/venv')
    if bin_folders:
      print("Found 'bin' folders:")
      for bin_folder in bin_folders:
        print(bin_folder)
        for filename in os.listdir(bin_folder):
            file_path = os.path.join(bin_folder, filename)
            if os.path.isfile(file_path):
                current_permissions = os.stat(file_path).st_mode
                 # Add execute permissions for the user, group, and others
                os.chmod(file_path, current_permissions | stat.S_IXUSR | stat.S_IXGRP | stat.S_IXOTH)'''

#if not os.path.exists(f'{home_dir}/venv/bin/python3.10'):
#    get_ipython().system('cp /usr/bin/python3.10 /kaggle/working/venv/bin/')
#!ln -s /kaggle/working/venv/bin/python3.10 /kaggle/working/venv/bin/python
#!ln -s /kaggle/working/venv/bin/python3.10 /kaggle/working/venv/bin/python3


# !apt-get update --yes 
# !apt-get upgrade --yes 
# !apt-get install --yes --no-install-recommends git wget curl bash nginx-light rsync sudo binutils ffmpeg lshw nano tzdata file build-essential nvtop libgl1 libglib2.0-0 clang libomp-dev ninja-build openssh-server ca-certificates
# !apt-get autoremove -y 
# !apt-get clean
#!rm -rf /var/lib/apt/lists/* /var/cache/apt/archives/*

# %cd /kaggle/working
# !git clone https://github.com/comfyanonymous/ComfyUI.git
# %cd /kaggle/working/ComfyUI
#!git checkout 7fc3ccdcc2fb1f20c4b7dd4aca374db952fd66df

# !{pip} install -r /kaggle/working/ComfyUI/requirements.txt

# !mkdir /tmp/models
# !mkdir /tmp/models/checkpoints
# !mkdir /tmp/models/clip
# !mkdir /tmp/models/vae
# !mkdir /tmp/models/unet

# Remove the following two lines to keep models in permanent storage
# !rm -rf /kaggle/working/ComfyUI/models/checkpoints
# !rm -rf /kaggle/working/ComfyUI/models/clip
# !rm -rf /kaggle/working/ComfyUI/models/vae
# !rm -rf /kaggle/working/ComfyUI/models/unet

# !ln -sf /tmp/models/checkpoints /kaggle/working/ComfyUI/models/checkpoints
# !ln -sf /tmp/models/clip /kaggle/working/ComfyUI/models/clip
# !ln -sf /tmp/models/vae /kaggle/working/ComfyUI/models/vae
# !ln -sf /tmp/models/unet /kaggle/working/ComfyUI/models/unet

checkpoints =  '/kaggle/working/ComfyUI/models/checkpoints'

#link_path = checkpoints + '/temp-models'
#temp_models = '/kaggle/temp/temp-models'

#!mkdir  /kaggle/temp/
#!mkdir -p $temp_models

#if not os.path.exists(link_path):
#    get_ipython().system(f'ln -s {temp_models} {checkpoints}')

# Install the node manager
#update_manager = True
# %cd /kaggle/working/ComfyUI/custom_nodes
# !git clone https://github.com/ltdrdata/ComfyUI-Manager.git
# %cd /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/
# !git pull 
# !pip install --no-cache-dir -r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt
#!git clone https://github.com/Comfy-Org/ComfyUI-Manager.git
#%cd ComfyUI-Manager
#!git pull
# !git clone https://github.com/farizrifqi/ComfyUI-Image-Saver.git
# !git clone https://github.com/M1kep/ComfyLiterals.git
# !git clone https://github.com/BadCafeCode/masquerade-nodes-comfyui.git
# !git clone https://github.com/orssorbit/ComfyUI-wanBlockswap.git
# !git clone https://github.com/SeanScripts/ComfyUI-Unload-Model.git
# !git clone https://github.com/Smirnov75/ComfyUI-mxToolkit.git
# !git clone https://github.com/pharmapsychotic/comfy-cliption.git
# !git clone https://github.com/facok/ComfyUI-HunyuanVideoMultiLora.git
# !git clone https://github.com/Hullabalo/ComfyUI-Loop.git
# !git clone https://github.com/chrisgoringe/cg-use-everywhere.git
# !git clone https://github.com/Flow-two/ComfyUI-WanStartEndFramesNative.git
# !git clone https://github.com/Chaoses-Ib/ComfyUI_Ib_CustomNodes.git
# !git clone https://github.com/JPS-GER/ComfyUI_JPS-Nodes.git
# !git clone https://github.com/city96/ComfyUI-GGUF.git
# !git clone https://github.com/welltop-cn/ComfyUI-TeaCache.git
# !git clone https://github.com/pythongosssss/ComfyUI-Custom-Scripts.git
# !git clone https://github.com/kijai/ComfyUI-Florence2.git
# !git clone https://github.com/shinich39/comfyui-get-meta.git
# !git clone https://github.com/bash-j/mikey_nodes.git
# !git clone https://github.com/kijai/ComfyUI-FramePackWrapper.git
# !git clone https://github.com/pollockjj/ComfyUI-MultiGPU.git
# !git clone https://github.com/farizrifqi/ComfyUI-Image-Saver.git
# !git clone https://github.com/cubiq/ComfyUI_essentials.git
# !git clone https://github.com/Fannovel16/ComfyUI-Frame-Interpolation.git
# !git clone https://github.com/1038lab/ComfyUI-RMBG.git
# !git clone https://github.com/ssitu/ComfyUI_UltimateSDUpscale.git
# !git clone https://github.com/alt-key-project/comfyui-dream-project.git
# !git clone https://github.com/kijai/ComfyUI-KJNodes.git
# !git clone https://github.com/Suzie1/ComfyUI_Comfyroll_CustomNodes.git
# !git clone https://github.com/Fannovel16/comfyui_controlnet_aux.git
# !git clone https://github.com/shenduldh/ComfyUI-Lightning.git
# !git clone https://github.com/ltdrdata/ComfyUI-Impact-Pack.git
# !git clone https://github.com/chflame163/ComfyUI_LayerStyle_Advance.git
# !git clone https://github.com/crystian/ComfyUI-Crystools.git
# !git clone https://github.com/jags111/efficiency-nodes-comfyui.git
# !git clone https://github.com/kijai/ComfyUI-MMAudio.git
# !git clone https://github.com/ltdrdata/ComfyUI-Inspire-Pack.git
# !git clone https://github.com/receyuki/comfyui-prompt-reader-node.git
# !git clone https://github.com/storyicon/comfyui_segment_anything.git
# !git clone https://github.com/ltdrdata/ComfyUI-Impact-Subpack.git
# !git clone https://github.com/Kosinkadink/ComfyUI-VideoHelperSuite.git
# !git clone https://github.com/rgthree/rgthree-comfy.git
# !git clone https://github.com/comfyanonymous/ComfyUI_TensorRT.git
# !git clone https://github.com/yolain/ComfyUI-Easy-Use.git
# !git clone https://github.com/DoctorDiffusion/ComfyUI-MediaMixer.git
# !git clone https://github.com/Gourieff/ComfyUI-ReActor.git
# !git clone https://github.com/ZHO-ZHO-ZHO/ComfyUI-Gemini.git
# !git clone https://github.com/justUmen/Bjornulf_custom_nodes.git
# !git clone https://github.com/yuvraj108c/ComfyUI-Upscaler-Tensorrt.git
# !git clone https://github.com/ShmuelRonen/ComfyUI-FramePackWrapper_Plus.git
# !git clone https://github.com/melMass/comfy_mtb.git
# !git clone https://github.com/if-ai/ComfyUI-IF_LLM.git
# !git clone https://github.com/kijai/ComfyUI-WanVideoWrapper.git
# !git clone https://github.com/chflame163/ComfyUI_LayerStyle.git
# !git clone https://github.com/aria1th/ComfyUI-LogicUtils.git
# !git clone https://github.com/MixLabPro/comfyui-mixlab-nodes.git
# !git clone https://github.com/WASasquatch/was-node-suite-comfyui.git

#if update_manager:
#    get_ipython().system('git pull')
# !git pull
# !{pip} install -r /kaggle/working/ComfyUI/custom_nodes/requirements.txt
# !python3 /kaggle/working/ComfyUI/custom_nodes/install.py

# Pinggy script
#!wget https://raw.githubusercontent.com/wandaweb/jupyter-webui-tunneling/main/pinggy.py -O /kaggle/working/pinggy.py
    
# Second GPU offload
# %cd /kaggle/working/ComfyUI/custom_nodes
# !wget https://gist.githubusercontent.com/city96/30743dfdfe129b331b5676a79c3a8a39/raw/ecb4f6f5202c20ea723186c93da308212ba04cfb/ComfyBootlegOffload.py
# Out:
# Error: Command '['/kaggle/working/venv/bin/python3', '-m', 'ensurepip', '--upgrade', '--default-pip']' returned non-zero exit status 1.
# Collecting virtualenv
#   Downloading virtualenv-20.31.2-py3-none-any.whl.metadata (4.5 kB)
# Collecting distlib<1,>=0.3.7 (from virtualenv)
#   Downloading distlib-0.3.9-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: filelock<4,>=3.12.2 in /usr/local/lib/python3.11/dist-packages (from virtualenv) (3.18.0)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /usr/local/lib/python3.11/dist-packages (from virtualenv) (4.3.8)
# Downloading virtualenv-20.31.2-py3-none-any.whl (6.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 67.0 MB/s eta 0:00:00:00:010:01
# Downloading distlib-0.3.9-py2.py3-none-any.whl (468 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 25.7 MB/s eta 0:00:00
# Installing collected packages: distlib, virtualenv
# Successfully installed distlib-0.3.9 virtualenv-20.31.2
# Found 'bin' folders:
# /kaggle/working/venv/bin
# ln: failed to create symbolic link '/kaggle/working/venv/bin/python': File exists
# ln: failed to create symbolic link '/kaggle/working/venv/bin/python3': File exists
# /kaggle/working
# Cloning into 'ComfyUI'...
# remote: Enumerating objects: 21350, done.
# remote: Total 21350 (delta 0), reused 0 (delta 0), pack-reused 21350 (from 1)
# Receiving objects: 100% (21350/21350), 71.35 MiB | 23.71 MiB/s, done.
# Resolving deltas: 100% (14210/14210), done.
# /kaggle/working/ComfyUI
# /bin/bash: line 1: /kaggle/working/venv/bin/pip: No such file or directory
# /kaggle/working/ComfyUI/custom_nodes
# Cloning into 'ComfyUI-Manager'...
# remote: Enumerating objects: 22201, done.
# remote: Counting objects: 100% (1030/1030), done.
# remote: Compressing objects: 100% (404/404), done.
# remote: Total 22201 (delta 842), reused 636 (delta 626), pack-reused 21171 (from 4)
# Receiving objects: 100% (22201/22201), 47.82 MiB | 31.61 MiB/s, done.
# Resolving deltas: 100% (16369/16369), done.
# /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager
# Already up to date.
# Requirement already satisfied: GitPython in /usr/local/lib/python3.11/dist-packages (from -r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 1)) (3.1.44)
# Collecting PyGithub (from -r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 2))
#   Downloading PyGithub-2.6.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting matrix-client==0.4.0 (from -r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 3))
#   Downloading matrix_client-0.4.0-py2.py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (from -r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 4)) (4.52.4)
# Requirement already satisfied: huggingface-hub>0.20 in /usr/local/lib/python3.11/dist-packages (from -r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 5)) (0.33.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.11/dist-packages (from -r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 6)) (0.16.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from -r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 7)) (14.0.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from -r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 8)) (4.14.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.11/dist-packages (from -r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 9)) (0.10.2)
# Collecting uv (from -r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 10))
#   Downloading uv-0.7.21-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: chardet in /usr/local/lib/python3.11/dist-packages (from -r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 11)) (5.2.0)
# Requirement already satisfied: requests~=2.22 in /usr/local/lib/python3.11/dist-packages (from matrix-client==0.4.0->-r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 3)) (2.32.4)
# Collecting urllib3~=1.21 (from matrix-client==0.4.0->-r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 3))
#   Downloading urllib3-1.26.20-py2.py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 198.4 MB/s eta 0:00:00
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from GitPython->-r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 1)) (4.0.12)
# Collecting pynacl>=1.4.0 (from PyGithub->-r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 2))
#   Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl.metadata (8.6 kB)
# Requirement already satisfied: pyjwt>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from pyjwt[crypto]>=2.4.0->PyGithub->-r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 2)) (2.10.1)
# Requirement already satisfied: Deprecated in /usr/local/lib/python3.11/dist-packages (from PyGithub->-r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 2)) (1.2.18)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers->-r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 4)) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers->-r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 4)) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers->-r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 4)) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers->-r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 4)) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers->-r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 4)) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers->-r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 4)) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers->-r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 4)) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers->-r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 4)) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>0.20->-r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 5)) (2025.5.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>0.20->-r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 5)) (1.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer->-r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 6)) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer->-r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 6)) (1.5.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->-r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 7)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->-r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 7)) (2.19.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->GitPython->-r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 1)) (5.0.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->-r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 7)) (0.1.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers->-r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 4)) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers->-r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 4)) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers->-r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 4)) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers->-r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 4)) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers->-r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 4)) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers->-r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 4)) (2.4.1)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/local/lib/python3.11/dist-packages (from pyjwt[crypto]>=2.4.0->PyGithub->-r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 2)) (44.0.3)
# Requirement already satisfied: cffi>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from pynacl>=1.4.0->PyGithub->-r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 2)) (1.17.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests~=2.22->matrix-client==0.4.0->-r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 3)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests~=2.22->matrix-client==0.4.0->-r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 3)) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests~=2.22->matrix-client==0.4.0->-r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 3)) (2025.6.15)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from Deprecated->PyGithub->-r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 2)) (1.17.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.4.1->pynacl>=1.4.0->PyGithub->-r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 2)) (2.22)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->transformers->-r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 4)) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->transformers->-r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 4)) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.17->transformers->-r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 4)) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.17->transformers->-r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 4)) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.17->transformers->-r /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt (line 4)) (2024.2.0)
# Downloading matrix_client-0.4.0-py2.py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 171.3 MB/s eta 0:00:00
# Downloading PyGithub-2.6.1-py3-none-any.whl (410 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.5/410.5 kB 48.2 MB/s eta 0:00:00
# Downloading uv-0.7.21-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.6/18.6 MB 276.5 MB/s eta 0:00:00 0:00:01
# Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (856 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 856.7/856.7 kB 303.3 MB/s eta 0:00:00
# Downloading urllib3-1.26.20-py2.py3-none-any.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.2/144.2 kB 290.8 MB/s eta 0:00:00
# Installing collected packages: uv, urllib3, pynacl, matrix-client, PyGithub
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.5.0
#     Uninstalling urllib3-2.5.0:
#       Successfully uninstalled urllib3-2.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.8.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# datasets 3.6.0 requires fsspec[http]<=2025.3.0,>=2023.1.0, but you have fsspec 2025.5.1 which is incompatible.
# google-colab 1.0.0 requires google-auth==2.38.0, but you have google-auth 2.40.3 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.4 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.1 which is incompatible.
# pandas-gbq 0.29.1 requires google-api-core<3.0.0,>=2.10.2, but you have google-api-core 1.34.1 which is incompatible.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.5.1 which is incompatible.
# langchain-core 0.3.66 requires packaging<25,>=23.2, but you have packaging 25.0 which is incompatible.
# google-cloud-storage 2.19.0 requires google-api-core<3.0.0dev,>=2.15.0, but you have google-api-core 1.34.1 which is incompatible.
# dataproc-spark-connect 0.7.5 requires google-api-core>=2.19, but you have google-api-core 1.34.1 which is incompatible.
# bigframes 2.8.0 requires google-cloud-bigquery[bqstorage,pandas]>=3.31.0, but you have google-cloud-bigquery 3.25.0 which is incompatible.
# bigframes 2.8.0 requires rich<14,>=12.4.4, but you have rich 14.0.0 which is incompatible.
# jupyter-kernel-gateway 2.5.2 requires jupyter-client<8.0,>=5.2.0, but you have jupyter-client 8.6.3 which is incompatible.
# Successfully installed PyGithub-2.6.1 matrix-client-0.4.0 pynacl-1.5.0 urllib3-1.26.20 uv-0.7.21
# Cloning into 'ComfyUI-Image-Saver'...
# remote: Enumerating objects: 185, done.
# remote: Counting objects: 100% (117/117), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 185 (delta 103), reused 95 (delta 95), pack-reused 68 (from 1)
# Receiving objects: 100% (185/185), 51.64 KiB | 3.44 MiB/s, done.
# Resolving deltas: 100% (116/116), done.
# Cloning into 'ComfyLiterals'...
# remote: Enumerating objects: 40, done.
# remote: Counting objects: 100% (40/40), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 40 (delta 18), reused 27 (delta 9), pack-reused 0 (from 0)
# Receiving objects: 100% (40/40), 12.54 KiB | 2.09 MiB/s, done.
# Resolving deltas: 100% (18/18), done.
# Cloning into 'masquerade-nodes-comfyui'...
# remote: Enumerating objects: 57, done.
# remote: Counting objects: 100% (22/22), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 57 (delta 15), reused 11 (delta 10), pack-reused 35 (from 1)
# Receiving objects: 100% (57/57), 49.84 KiB | 3.56 MiB/s, done.
# Resolving deltas: 100% (29/29), done.
# Cloning into 'ComfyUI-wanBlockswap'...
# remote: Enumerating objects: 49, done.
# remote: Counting objects: 100% (49/49), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 49 (delta 19), reused 40 (delta 12), pack-reused 0 (from 0)
# Receiving objects: 100% (49/49), 490.36 KiB | 12.57 MiB/s, done.
# Resolving deltas: 100% (19/19), done.
# Cloning into 'ComfyUI-Unload-Model'...
# remote: Enumerating objects: 47, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 47 (delta 22), reused 36 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (47/47), 8.60 KiB | 8.60 MiB/s, done.
# Resolving deltas: 100% (22/22), done.
# Cloning into 'ComfyUI-mxToolkit'...
# remote: Enumerating objects: 300, done.
# remote: Counting objects: 100% (141/141), done.
# remote: Compressing objects: 100% (137/137), done.
# remote: Total 300 (delta 90), reused 7 (delta 2), pack-reused 159 (from 1)
# Receiving objects: 100% (300/300), 169.44 KiB | 7.06 MiB/s, done.
# Resolving deltas: 100% (183/183), done.
# Cloning into 'comfy-cliption'...
# remote: Enumerating objects: 82, done.
# remote: Counting objects: 100% (82/82), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 82 (delta 30), reused 70 (delta 21), pack-reused 0 (from 0)
# Receiving objects: 100% (82/82), 1.24 MiB | 21.90 MiB/s, done.
# Resolving deltas: 100% (30/30), done.
# Cloning into 'ComfyUI-HunyuanVideoMultiLora'...
# remote: Enumerating objects: 66, done.
# remote: Counting objects: 100% (66/66), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 66 (delta 27), reused 25 (delta 11), pack-reused 0 (from 0)
# Receiving objects: 100% (66/66), 23.44 KiB | 4.69 MiB/s, done.
# Resolving deltas: 100% (27/27), done.
# Cloning into 'ComfyUI-Loop'...
# remote: Enumerating objects: 314, done.
# remote: Counting objects: 100% (70/70), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 314 (delta 58), reused 26 (delta 26), pack-reused 244 (from 2)
# Receiving objects: 100% (314/314), 17.03 MiB | 24.05 MiB/s, done.
# Resolving deltas: 100% (152/152), done.
# Cloning into 'cg-use-everywhere'...
# remote: Enumerating objects: 1820, done.
# remote: Counting objects: 100% (398/398), done.
# remote: Compressing objects: 100% (173/173), done.
# remote: Total 1820 (delta 288), reused 270 (delta 225), pack-reused 1422 (from 1)
# Receiving objects: 100% (1820/1820), 9.03 MiB | 36.26 MiB/s, done.
# Resolving deltas: 100% (1298/1298), done.
# Cloning into 'ComfyUI-WanStartEndFramesNative'...
# remote: Enumerating objects: 130, done.
# remote: Counting objects: 100% (130/130), done.
# remote: Compressing objects: 100% (87/87), done.
# remote: Total 130 (delta 73), reused 80 (delta 35), pack-reused 0 (from 0)
# Receiving objects: 100% (130/130), 5.92 MiB | 35.47 MiB/s, done.
# Resolving deltas: 100% (73/73), done.
# Cloning into 'ComfyUI_Ib_CustomNodes'...
# remote: Enumerating objects: 46, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 46 (delta 23), reused 36 (delta 14), pack-reused 0 (from 0)
# Receiving objects: 100% (46/46), 101.47 KiB | 5.34 MiB/s, done.
# Resolving deltas: 100% (23/23), done.
# Cloning into 'ComfyUI_JPS-Nodes'...
# remote: Enumerating objects: 300, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 300 (delta 4), reused 2 (delta 0), pack-reused 284 (from 1)
# Receiving objects: 100% (300/300), 136.82 KiB | 5.07 MiB/s, done.
# Resolving deltas: 100% (125/125), done.
# Cloning into 'ComfyUI-GGUF'...
# remote: Enumerating objects: 631, done.
# remote: Counting objects: 100% (305/305), done.
# remote: Compressing objects: 100% (139/139), done.
# remote: Total 631 (delta 269), reused 170 (delta 166), pack-reused 326 (from 2)
# Receiving objects: 100% (631/631), 184.24 KiB | 7.37 MiB/s, done.
# Resolving deltas: 100% (401/401), done.
# Cloning into 'ComfyUI-TeaCache'...
# remote: Enumerating objects: 348, done.
# remote: Counting objects: 100% (102/102), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 348 (delta 69), reused 71 (delta 49), pack-reused 246 (from 1)
# Receiving objects: 100% (348/348), 44.46 MiB | 41.02 MiB/s, done.
# Resolving deltas: 100% (194/194), done.
# Cloning into 'ComfyUI-Custom-Scripts'...
# remote: Enumerating objects: 2329, done.
# remote: Counting objects: 100% (726/726), done.
# remote: Compressing objects: 100% (138/138), done.
# remote: Total 2329 (delta 652), reused 588 (delta 588), pack-reused 1603 (from 2)
# Receiving objects: 100% (2329/2329), 540.70 KiB | 12.02 MiB/s, done.
# Resolving deltas: 100% (1387/1387), done.
# Cloning into 'ComfyUI-Florence2'...
# remote: Enumerating objects: 274, done.
# remote: Counting objects: 100% (172/172), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 274 (delta 151), reused 149 (delta 140), pack-reused 102 (from 1)
# Receiving objects: 100% (274/274), 83.67 KiB | 6.44 MiB/s, done.
# Resolving deltas: 100% (154/154), done.
# Cloning into 'comfyui-get-meta'...
# remote: Enumerating objects: 58, done.
# remote: Counting objects: 100% (58/58), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 58 (delta 23), reused 45 (delta 10), pack-reused 0 (from 0)
# Receiving objects: 100% (58/58), 19.22 KiB | 9.61 MiB/s, done.
# Resolving deltas: 100% (23/23), done.
# Cloning into 'mikey_nodes'...
# remote: Enumerating objects: 692, done.
# remote: Counting objects: 100% (81/81), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 692 (delta 57), reused 59 (delta 46), pack-reused 611 (from 1)
# Receiving objects: 100% (692/692), 45.42 MiB | 40.94 MiB/s, done.
# Resolving deltas: 100% (416/416), done.
# Cloning into 'ComfyUI-FramePackWrapper'...
# remote: Enumerating objects: 158, done.
# remote: Counting objects: 100% (92/92), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 158 (delta 71), reused 58 (delta 57), pack-reused 66 (from 1)
# Receiving objects: 100% (158/158), 73.85 KiB | 4.62 MiB/s, done.
# Resolving deltas: 100% (75/75), done.
# Cloning into 'ComfyUI-MultiGPU'...
# remote: Enumerating objects: 592, done.
# remote: Counting objects: 100% (74/74), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 592 (delta 60), reused 52 (delta 51), pack-reused 518 (from 2)
# Receiving objects: 100% (592/592), 14.50 MiB | 38.97 MiB/s, done.
# Resolving deltas: 100% (354/354), done.
# fatal: destination path 'ComfyUI-Image-Saver' already exists and is not an empty directory.
# Cloning into 'ComfyUI_essentials'...
# remote: Enumerating objects: 480, done.
# remote: Counting objects: 100% (147/147), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 480 (delta 125), reused 114 (delta 114), pack-reused 333 (from 2)
# Receiving objects: 100% (480/480), 166.13 KiB | 7.91 MiB/s, done.
# Resolving deltas: 100% (287/287), done.
# Cloning into 'ComfyUI-Frame-Interpolation'...
# remote: Enumerating objects: 1096, done.
# remote: Counting objects: 100% (147/147), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 1096 (delta 125), reused 119 (delta 114), pack-reused 949 (from 2)
# Receiving objects: 100% (1096/1096), 79.78 MiB | 33.69 MiB/s, done.
# Resolving deltas: 100% (626/626), done.
# Cloning into 'ComfyUI-RMBG'...
# remote: Enumerating objects: 899, done.
# remote: Counting objects: 100% (338/338), done.
# remote: Compressing objects: 100% (147/147), done.
# remote: Total 899 (delta 314), reused 191 (delta 191), pack-reused 561 (from 1)
# Receiving objects: 100% (899/899), 434.16 KiB | 10.85 MiB/s, done.
# Resolving deltas: 100% (535/535), done.
# Cloning into 'ComfyUI_UltimateSDUpscale'...
# remote: Enumerating objects: 413, done.
# remote: Counting objects: 100% (240/240), done.
# remote: Compressing objects: 100% (69/69), done.
# remote: Total 413 (delta 202), reused 172 (delta 171), pack-reused 173 (from 3)
# Receiving objects: 100% (413/413), 102.25 KiB | 6.39 MiB/s, done.
# Resolving deltas: 100% (245/245), done.
# Cloning into 'comfyui-dream-project'...
# remote: Enumerating objects: 661, done.
# remote: Counting objects: 100% (101/101), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 661 (delta 63), reused 60 (delta 32), pack-reused 560 (from 1)
# Receiving objects: 100% (661/661), 3.72 MiB | 31.46 MiB/s, done.
# Resolving deltas: 100% (445/445), done.
# Cloning into 'ComfyUI-KJNodes'...
# remote: Enumerating objects: 3244, done.
# remote: Counting objects: 100% (692/692), done.
# remote: Compressing objects: 100% (193/193), done.
# remote: Total 3244 (delta 566), reused 516 (delta 499), pack-reused 2552 (from 3)
# Receiving objects: 100% (3244/3244), 24.93 MiB | 35.90 MiB/s, done.
# Resolving deltas: 100% (2201/2201), done.
# Cloning into 'ComfyUI_Comfyroll_CustomNodes'...
# remote: Enumerating objects: 2600, done.
# remote: Counting objects: 100% (279/279), done.
# remote: Compressing objects: 100% (80/80), done.
# remote: Total 2600 (delta 243), reused 199 (delta 199), pack-reused 2321 (from 2)
# Receiving objects: 100% (2600/2600), 3.45 MiB | 24.86 MiB/s, done.
# Resolving deltas: 100% (1736/1736), done.
# Cloning into 'comfyui_controlnet_aux'...
# remote: Enumerating objects: 5553, done.
# remote: Counting objects: 100% (1847/1847), done.
# remote: Compressing objects: 100% (388/388), done.
# remote: Total 5553 (delta 1586), reused 1459 (delta 1459), pack-reused 3706 (from 2)
# Receiving objects: 100% (5553/5553), 42.86 MiB | 36.94 MiB/s, done.
# Resolving deltas: 100% (3006/3006), done.
# Cloning into 'ComfyUI-Lightning'...
# remote: Enumerating objects: 289, done.
# remote: Counting objects: 100% (289/289), done.
# remote: Compressing objects: 100% (210/210), done.
# remote: Total 289 (delta 133), reused 229 (delta 73), pack-reused 0 (from 0)
# Receiving objects: 100% (289/289), 4.31 MiB | 32.22 MiB/s, done.
# Resolving deltas: 100% (133/133), done.
# Cloning into 'ComfyUI-Impact-Pack'...
# remote: Enumerating objects: 5750, done.
# remote: Counting objects: 100% (431/431), done.
# remote: Compressing objects: 100% (131/131), done.
# remote: Total 5750 (delta 369), reused 305 (delta 300), pack-reused 5319 (from 3)
# Receiving objects: 100% (5750/5750), 33.04 MiB | 41.83 MiB/s, done.
# Resolving deltas: 100% (3788/3788), done.
# Cloning into 'ComfyUI_LayerStyle_Advance'...
# remote: Enumerating objects: 933, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 933 (delta 36), reused 28 (delta 28), pack-reused 881 (from 2)
# Receiving objects: 100% (933/933), 32.05 MiB | 36.14 MiB/s, done.
# Resolving deltas: 100% (320/320), done.
# Cloning into 'ComfyUI-Crystools'...
# remote: Enumerating objects: 1953, done.
# remote: Counting objects: 100% (349/349), done.
# remote: Compressing objects: 100% (100/100), done.
# remote: Total 1953 (delta 251), reused 249 (delta 249), pack-reused 1604 (from 1)
# Receiving objects: 100% (1953/1953), 15.51 MiB | 35.52 MiB/s, done.
# Resolving deltas: 100% (1284/1284), done.
# Cloning into 'efficiency-nodes-comfyui'...
# remote: Enumerating objects: 1633, done.
# remote: Counting objects: 100% (508/508), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 1633 (delta 461), reused 432 (delta 432), pack-reused 1125 (from 3)
# Receiving objects: 100% (1633/1633), 330.10 MiB | 42.37 MiB/s, done.
# Resolving deltas: 100% (881/881), done.
# Cloning into 'ComfyUI-MMAudio'...
# remote: Enumerating objects: 209, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 209 (delta 11), reused 9 (delta 9), pack-reused 191 (from 1)
# Receiving objects: 100% (209/209), 101.57 KiB | 4.42 MiB/s, done.
# Resolving deltas: 100% (87/87), done.
# Cloning into 'ComfyUI-Inspire-Pack'...
# remote: Enumerating objects: 1647, done.
# remote: Counting objects: 100% (379/379), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 1647 (delta 338), reused 329 (delta 326), pack-reused 1268 (from 1)
# Receiving objects: 100% (1647/1647), 309.44 KiB | 9.67 MiB/s, done.
# Resolving deltas: 100% (1197/1197), done.
# Cloning into 'comfyui-prompt-reader-node'...
# remote: Enumerating objects: 673, done.
# remote: Counting objects: 100% (207/207), done.
# remote: Compressing objects: 100% (61/61), done.
# remote: Total 673 (delta 173), reused 166 (delta 144), pack-reused 466 (from 1)
# Receiving objects: 100% (673/673), 18.33 MiB | 38.16 MiB/s, done.
# Resolving deltas: 100% (353/353), done.
# Cloning into 'comfyui_segment_anything'...
# remote: Enumerating objects: 91, done.
# remote: Counting objects: 100% (58/58), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 91 (delta 24), reused 17 (delta 17), pack-reused 33 (from 1)
# Receiving objects: 100% (91/91), 172.09 KiB | 5.38 MiB/s, done.
# Resolving deltas: 100% (24/24), done.
# Cloning into 'ComfyUI-Impact-Subpack'...
# remote: Enumerating objects: 353, done.
# remote: Counting objects: 100% (107/107), done.
# remote: Compressing objects: 100% (58/58), done.
# remote: Total 353 (delta 72), reused 72 (delta 49), pack-reused 246 (from 2)
# Receiving objects: 100% (353/353), 85.77 KiB | 5.72 MiB/s, done.
# Resolving deltas: 100% (165/165), done.
# Cloning into 'ComfyUI-VideoHelperSuite'...
# remote: Enumerating objects: 2996, done.
# remote: Counting objects: 100% (1386/1386), done.
# remote: Compressing objects: 100% (297/297), done.
# remote: Total 2996 (delta 1268), reused 1090 (delta 1088), pack-reused 1610 (from 2)
# Receiving objects: 100% (2996/2996), 719.72 KiB | 12.85 MiB/s, done.
# Resolving deltas: 100% (1762/1762), done.
# Cloning into 'rgthree-comfy'...
# remote: Enumerating objects: 4179, done.
# remote: Counting objects: 100% (992/992), done.
# remote: Compressing objects: 100% (351/351), done.
# remote: Total 4179 (delta 748), reused 703 (delta 641), pack-reused 3187 (from 3)
# Receiving objects: 100% (4179/4179), 4.72 MiB | 15.59 MiB/s, done.
# Resolving deltas: 100% (2961/2961), done.
# Cloning into 'ComfyUI_TensorRT'...
# remote: Enumerating objects: 119, done.
# remote: Counting objects: 100% (74/74), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 119 (delta 66), reused 54 (delta 54), pack-reused 45 (from 1)
# Receiving objects: 100% (119/119), 2.03 MiB | 27.71 MiB/s, done.
# Resolving deltas: 100% (66/66), done.
# Cloning into 'ComfyUI-Easy-Use'...
# remote: Enumerating objects: 4996, done.
# remote: Counting objects: 100% (1410/1410), done.
# remote: Compressing objects: 100% (393/393), done.
# remote: Total 4996 (delta 1129), reused 1049 (delta 1017), pack-reused 3586 (from 3)
# Receiving objects: 100% (4996/4996), 14.23 MiB | 30.10 MiB/s, done.
# Resolving deltas: 100% (3376/3376), done.
# Cloning into 'ComfyUI-MediaMixer'...
# remote: Enumerating objects: 127, done.
# remote: Counting objects: 100% (127/127), done.
# remote: Compressing objects: 100% (125/125), done.
# remote: Total 127 (delta 72), reused 1 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (127/127), 52.64 KiB | 3.10 MiB/s, done.
# Resolving deltas: 100% (72/72), done.
# Cloning into 'ComfyUI-ReActor'...
# remote: Enumerating objects: 432, done.
# remote: Counting objects: 100% (131/131), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 432 (delta 108), reused 90 (delta 90), pack-reused 301 (from 2)
# Receiving objects: 100% (432/432), 370.33 KiB | 8.05 MiB/s, done.
# Resolving deltas: 100% (189/189), done.
# Cloning into 'ComfyUI-Gemini'...
# remote: Enumerating objects: 236, done.
# remote: Counting objects: 100% (108/108), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 236 (delta 61), reused 98 (delta 54), pack-reused 128 (from 1)
# Receiving objects: 100% (236/236), 85.97 KiB | 5.37 MiB/s, done.
# Resolving deltas: 100% (129/129), done.
# Cloning into 'Bjornulf_custom_nodes'...
# remote: Enumerating objects: 5079, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 5079 (delta 0), reused 0 (delta 0), pack-reused 5076 (from 2)
# Receiving objects: 100% (5079/5079), 431.03 MiB | 41.28 MiB/s, done.
# Resolving deltas: 100% (855/855), done.
# Cloning into 'ComfyUI-Upscaler-Tensorrt'...
# remote: Enumerating objects: 186, done.
# remote: Counting objects: 100% (82/82), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 186 (delta 70), reused 51 (delta 51), pack-reused 104 (from 1)
# Receiving objects: 100% (186/186), 1.03 MiB | 20.71 MiB/s, done.
# Resolving deltas: 100% (98/98), done.
# Cloning into 'ComfyUI-FramePackWrapper_Plus'...
# remote: Enumerating objects: 74, done.
# remote: Counting objects: 100% (74/74), done.
# remote: Compressing objects: 100% (74/74), done.
# remote: Total 74 (delta 31), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (74/74), 71.90 KiB | 4.23 MiB/s, done.
# Resolving deltas: 100% (31/31), done.
# Cloning into 'comfy_mtb'...
# remote: Enumerating objects: 3193, done.
# remote: Counting objects: 100% (993/993), done.
# remote: Compressing objects: 100% (385/385), done.
# remote: Total 3193 (delta 769), reused 658 (delta 607), pack-reused 2200 (from 2)
# Receiving objects: 100% (3193/3193), 7.48 MiB | 28.16 MiB/s, done.
# Resolving deltas: 100% (1921/1921), done.
# Cloning into 'ComfyUI-IF_LLM'...
# remote: Enumerating objects: 572, done.
# remote: Counting objects: 100% (129/129), done.
# remote: Compressing objects: 100% (74/74), done.
# remote: Total 572 (delta 86), reused 51 (delta 51), pack-reused 443 (from 4)
# Receiving objects: 100% (572/572), 17.49 MiB | 23.17 MiB/s, done.
# Resolving deltas: 100% (313/313), done.
# Cloning into 'ComfyUI-WanVideoWrapper'...
# remote: Enumerating objects: 2494, done.
# remote: Counting objects: 100% (1701/1701), done.
# remote: Compressing objects: 100% (587/587), done.
# remote: Total 2494 (delta 1308), reused 1138 (delta 1114), pack-reused 793 (from 3)
# Receiving objects: 100% (2494/2494), 22.74 MiB | 28.78 MiB/s, done.
# Resolving deltas: 100% (1681/1681), done.
# Cloning into 'ComfyUI_LayerStyle'...
# remote: Enumerating objects: 4647, done.
# remote: Counting objects: 100% (88/88), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 4647 (delta 49), reused 45 (delta 44), pack-reused 4559 (from 2)
# Receiving objects: 100% (4647/4647), 219.70 MiB | 39.42 MiB/s, done.
# Resolving deltas: 100% (2800/2800), done.
# Cloning into 'ComfyUI-LogicUtils'...
# remote: Enumerating objects: 398, done.
# remote: Counting objects: 100% (79/79), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 398 (delta 56), reused 64 (delta 48), pack-reused 319 (from 1)
# Receiving objects: 100% (398/398), 131.90 KiB | 6.94 MiB/s, done.
# Resolving deltas: 100% (231/231), done.
# Cloning into 'comfyui-mixlab-nodes'...
# remote: Enumerating objects: 5387, done.
# remote: Counting objects: 100% (595/595), done.
# remote: Compressing objects: 100% (494/494), done.
# remote: Total 5387 (delta 109), reused 102 (delta 100), pack-reused 4792 (from 3)
# Receiving objects: 100% (5387/5387), 104.79 MiB | 34.56 MiB/s, done.
# Resolving deltas: 100% (3457/3457), done.
# Cloning into 'was-node-suite-comfyui'...
# remote: Enumerating objects: 2390, done.
# remote: Counting objects: 100% (888/888), done.
# remote: Compressing objects: 100% (187/187), done.
# remote: Total 2390 (delta 821), reused 703 (delta 701), pack-reused 1502 (from 2)
# Receiving objects: 100% (2390/2390), 39.52 MiB | 32.69 MiB/s, done.
# Resolving deltas: 100% (1453/1453), done.
# Already up to date.
# /bin/bash: line 1: /kaggle/working/venv/bin/pip: No such file or directory
# python3: can't open file '/kaggle/working/ComfyUI/custom_nodes/install.py': [Errno 2] No such file or directory
# /kaggle/working/ComfyUI/custom_nodes
# --2025-07-16 23:35:48--  https://gist.githubusercontent.com/city96/30743dfdfe129b331b5676a79c3a8a39/raw/ecb4f6f5202c20ea723186c93da308212ba04cfb/ComfyBootlegOffload.py
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2164 (2.1K) [text/plain]
# Saving to: ‘ComfyBootlegOffload.py’
#
# ComfyBootlegOffload 100%[===================>]   2.11K  --.-KB/s    in 0s
#
# 2025-07-16 23:35:48 (25.1 MB/s) - ‘ComfyBootlegOffload.py’ saved [2164/2164]
#
# CPU times: user 2.73 s, sys: 1.04 s, total: 3.77 s
# Wall time: 2min 3s

# %% [markdown]
# ---
# # WebUI

# %% [markdown]
# ## Start the WebUI with Pinggy
# * Wait for the GUI to start.
# * Click the link that ends with .pinggy.link 😁
# * If generation is still running after the link expires in an hour, wait for the generation to complete and restart the WebUI code block to get a new link

# %%
# Starting the Web UI with pinggy

# %cd /kaggle/working/ComfyUI
# !python /kaggle/working/pinggy.py --command='/kaggle/working/venv/bin/python /kaggle/working/ComfyUI/main.py' --port=8188
# Out:
# /kaggle/working/ComfyUI
# 8188
# /kaggle/working/venv/bin/python /kaggle/working/ComfyUI/main.py
# Port 8188 is free.
# /kaggle/working/venv/bin/python /kaggle/working/ComfyUI/main.py
# waiting for output
# Error in sitecustomize; set PYTHONVERBOSE for traceback:
# ModuleNotFoundError: No module named 'log'
# Traceback (most recent call last):
#   File "/kaggle/working/ComfyUI/main.py", line 11, in <module>
#     import utils.extra_config
#   File "/kaggle/working/ComfyUI/utils/extra_config.py", line 2, in <module>
#     import yaml
# ModuleNotFoundError: No module named 'yaml'
# Allocated port 2 for remote forward to localhost:8188
# 😁 😁 😁
# URL: http://rneli-34-45-111-171.a.free.pinggy.link
# 😁 😁 😁
# 7=)0]8;;\                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ┌────────────────────────────┐                                                  │                            │                                                  │ Wait while we prepare the  │                                                  │             UI             │                                                  │                            │                                                  │                            │                                                  │                            │                                                  └────────────────────────────┘                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ]8;;\]8;;\┌────────────────────────────┐│││Waitwhilewepreparethe││UI│││││││└────────────────────────────┘]8;;\Youarenotauthenticated.Yourtunnelwillexpirein60minutes.UpgradetoPinggyProtogetunrestrictedtunnels.https://dashboard.pinggy.iohttp://rneli-34-45-111-171.a.free.pinggy.linkhttps://rneli-34-45-111-171.a.free.pinggy.link                                                                                               Press`h`forkeybindings
# Connection to a.pinggy.io closed by remote host.
# Connection to a.pinggy.io closed.

# %% [markdown]
# ## Start the WebUI with Zrok
#
# ### Install Zrok

# %%
# Install Zrok (only needs to run once)

# !mkdir /kaggle/working/zrok
# %cd /kaggle/working/zrok
# !rm zrok*.gz
# !wget https://github.com/openziti/zrok/releases/download/v1.0.4/zrok_1.0.4_linux_amd64.tar.gz
# !tar -xvf ./zrok*.gz 
# !chmod a+x /kaggle/working/zrok/zrok

# %% [markdown]
# ### Create a Zrok account
# Enter your email address in the email variable

# %%
email = '####@gmail.com' # replace with your email

# --------------

cmd = '/kaggle/working/zrok/zrok invite'
log = '/kaggle/working/zrok/log.txt'

# !pip install pexpect
# !touch $log

import pexpect
import time
child = pexpect.spawn('bash')
child.sendline(f'{cmd} | tee {log}')
child.expect('enter and confirm your email address...')
time.sleep(1); child.sendline(email); time.sleep(1); child.send(chr(9)); time.sleep(1)
child.sendline(email); time.sleep(1); child.send('\n'); time.sleep(1); child.send(chr(9))
time.sleep(1); child.send('\r\n'); time.sleep(2); child.close()
# !cat $log
# !rm $log

# %% [markdown]
# ### Enable Zrok
# Paste your Zrok token in the token variable

# %%
# Enable Zrok (needs to run once per instance)
# Paste your Zrok token in the token variable

token = ""
# !chmod a+x /kaggle/working/zrok/zrok 
# !/kaggle/working/zrok/zrok enable $token

# %% [markdown]
# ### Start the WebUI with Zrok

# %%
# Start the WebUI with Zrok
# %cd /kaggle/working/ComfyUI
command = '/kaggle/working/venv/bin/python /kaggle/working/ComfyUI/main.py'
port = '8188'
# ------------------------

# !chmod a+x /kaggle/working/zrok/zrok 
cmd = f'{command} & /kaggle/working/zrok/zrok share public http://localhost:{port} --headless'
get_ipython().system(cmd)

# %% [markdown]
# ---
# # Model Management

# %% [markdown]
# ## Install a model
#
# Copy the model URL to the model_url field. Make sure the model can be accessed publicly, without being signed into a website.

# %%
#### Install a model in permanent storage
# Make sure Persistence is set to "Files only" or "Variables and Files"
model_url = 'https://civitai.com/api/download/models/782002'
model_name = 'JuggernautXL.safetensors'

# %cd $checkpoints
get_ipython().system(f'wget -O "{model_name}" "{model_url}"')

# %%
# Install a LoRA in permanent storage
model_url = 'https://civitai.com/api/download/models/137124?type=Model&format=SafeTensor'
model_name = 'DreamArt.safetensors'

# %cd /kaggle/working/ComfyUI/models/loras
get_ipython().system(f'wget -O "{model_name}" "{model_url}"')

# %%
# Install a model in temporary storage
#model_url = 'https://civitai.com/api/download/models/160191?type=Model&format=SafeTensor&size=full&fp=fp16'
#model_name = 'YamersRealism.safetensors'
model_url = 'https://civitai.com/api/download/models/456751'
model_name = 'HelloWorld-XL.safetensors' 

# %cd $temp_models
get_ipython().system(f'wget -O "{model_name}" "{model_url}"')

# %% [markdown]
# ## Download a model for a custom node

# %%
model_folder = '/kaggle/working/ComfyUI/custom_nodes/my_node/models'
model_url = ''
model_name = 'model.safetensors'

# %cd $model_folder
get_ipython().system(f'wget -O "{model_name}" "{model_url}"')

# %% [markdown]
# ---
# # File Browser

# %% [markdown]
# ## Install FileBrowser

# %%
# %cd /kaggle
# !wget https://github.com/filebrowser/filebrowser/releases/download/v2.27.0/linux-amd64-filebrowser.tar.gz
# !tar xvfz linux-amd64-filebrowser.tar.gz
# !chmod a+x /kaggle/filebrowser
# !/kaggle/filebrowser config init 
# !/kaggle/filebrowser config set --auth.method=noauth > /dev/null
# !/kaggle/filebrowser config set --branding.theme=dark > /dev/null
# !/kaggle/filebrowser users add admin admin 
# !/kaggle/filebrowser config export "/kaggle/config.json"

# %% [markdown]
# ## Run FileBrowser

# %%
# %cd /kaggle
# !chmod a+x /kaggle/filebrowser

# !python /kaggle/working/pinggy.py --command='/kaggle/filebrowser -c "/kaggle/working/config.json"' --port=8080

# %% [markdown]
# #
# # Delete a model

# %%
# List permanent models
# !ls -la $checkpoints

# Delete a model
model_to_delete = '/kaggle/working/ComfyUI/models/checkpoints/model.safetensors'
# !rm $model_to_delete

# %%
# Check the size of a model
# !du -sh /kaggle/working/ComfyUI/models/loras/harrlogos.safetensors

# %% [markdown]
# #
# # Delete everything in the working folder

# %%
# Delete the working folder
# !rm -rf /kaggle/working/*
