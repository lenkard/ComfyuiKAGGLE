# %%
# !add-apt-repository ppa:deadsnakes/ppa -y
# !apt update
# !apt dist-upgrade
# !apt autoremove
# !apt install python3.12 python3.12-venv
# !/usr/bin/python3.12 -m venv /kaggle/working/venv
# !source /kaggle/working/venv/bin/activate
# !/kaggle/working/venv/bin/python -m pip install --upgrade pip

# !/kaggle/working/venv/bin/pip install --no-cache-dir uv setuptools wheel jupyterlab jupyterlab_widgets ipykernel ipywidgets huggingface_hub hf_transfer numpy
# !/kaggle/working/venv/bin/pip install --no-cache-dir scipy matplotlib pandas scikit-learn seaborn requests tqdm pillow pyyaml triton sageattention onnxruntime-gpu
# !/kaggle/working/venv/bin/pip install --no-cache-dir torch==2.7.0 torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu126
#!/kaggle/working/venv/bin/pip install --no-cache-dir https://pypi.tuna.tsinghua.edu.cn/packages/ee/1e/6395bbe0db665f187c8e49266cda54fcf661f182192370d409423e4943e4/insightface-0.2.1-py2.py3-none-any.whl#sha256=c18cc93de32a21b6bde2990214fc23a66d39eeccb438ef11b39fae21e519f6ac
#!/kaggle/working/venv/bin/pip install --no-cache-dir /kaggle/input/insightface-7-3-cp12/insightface-0.7.3-cp312-cp312-linux_x86_64.whl
#!/kaggle/working/venv/bin/pip install --no-cache-dir /kaggle/input/nsightface-021/insightface-0.2.1-py2.py3-none-any.whl 
#!/kaggle/working/venv/bin/pip install --no-cache-dir https://github.com/nunchaku-tech/nunchaku/releases/download/v0.3.1/nunchaku-0.3.1+torch2.7-cp312-cp312-linux_x86_64.whl
#!/kaggle/working/venv/bin/pip install --no-cache-dir tensorflow[and-cuda]

# Install ComfyUI and ComfyUI Manager
#-b worksplit-multigpu
# %cd /kaggle/working/
# !git clone -b worksplit-multigpu https://github.com/comfyanonymous/ComfyUI.git
# %cd /kaggle/working/ComfyUI
# !git pull
# !/kaggle/working/venv/bin/pip install --no-cache-dir -r requirements.txt
# Install ComfyUI Manager
# %cd /kaggle/working/ComfyUI/custom_nodes
# !git clone https://github.com/ltdrdata/ComfyUI-Manager.git
# %cd /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Manager
# !git pull
# !/kaggle/working/venv/bin/pip install --no-cache-dir -r requirements.txt
# Install ComfyUI-Crystools
# %cd /kaggle/working/ComfyUI/custom_nodes
# !git clone https://github.com/crystian/ComfyUI-Crystools.git
# %cd /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Crystools
# !git pull
# !/kaggle/working/venv/bin/pip install --no-cache-dir -r requirements.txt
# Install ComfyUI-GGUF
# %cd /kaggle/working/ComfyUI/custom_nodes
# !git clone https://github.com/city96/ComfyUI-GGUF.git
# %cd /kaggle/working/ComfyUI/custom_nodes/ComfyUI-GGUF
# !git pull
# !/kaggle/working/venv/bin/pip install --no-cache-dir -r requirements.txt
#Install Comfyui Login
# %cd /kaggle/working/ComfyUI/custom_nodes
# !git clone https://github.com/liusida/ComfyUI-Login.git
# %cd /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Login
# !git pull
# !/kaggle/working/venv/bin/pip install --no-cache-dir -r requirements.txt
#Install ComfyUI-KJNodes
# %cd /kaggle/working/ComfyUI/custom_nodes
# !git clone https://github.com/kijai/ComfyUI-KJNodes.git
# %cd /kaggle/working/ComfyUI/custom_nodes/ComfyUI-KJNodes
# !git pull
# !/kaggle/working/venv/bin/pip install --no-cache-dir -r requirements.txt
#Install ComfyUI-VideoHelperSuite
# %cd /kaggle/working/ComfyUI/custom_nodes
# !git clone https://github.com/Kosinkadink/ComfyUI-VideoHelperSuite.git
# %cd /kaggle/working/ComfyUI/custom_nodes/ComfyUI-VideoHelperSuite
# !git pull
# !/kaggle/working/venv/bin/pip install --no-cache-dir -r requirements.txt
#Install comfyui_controlnet_aux
# %cd /kaggle/working/ComfyUI/custom_nodes
# !git clone https://github.com/Fannovel16/comfyui_controlnet_aux.git
# %cd /kaggle/working/ComfyUI/custom_nodes/comfyui_controlnet_aux
# !git pull
# !/kaggle/working/venv/bin/pip install --no-cache-dir -r requirements.txt
#Install ComfyUI-TeaCache
# %cd /kaggle/working/ComfyUI/custom_nodes
# !git clone https://github.com/welltop-cn/ComfyUI-TeaCache.git
# %cd /kaggle/working/ComfyUI/custom_nodes/ComfyUI-TeaCache
# !git pull
# !/kaggle/working/venv/bin/pip install --no-cache-dir -r requirements.txt
#Install WanVideoWrapper
# %cd /kaggle/working/ComfyUI/custom_nodes
# !git clone https://github.com/kijai/ComfyUI-WanVideoWrapper.git
# %cd /kaggle/working/ComfyUI/custom_nodes/ComfyUI-WanVideoWrapper
# !git pull
# !/kaggle/working/venv/bin/pip install --no-cache-dir -r requirements.txt
#Install ComfyUI-MultiGPU
# %cd /kaggle/working/ComfyUI/custom_nodes
# !git clone https://github.com/pollockjj/ComfyUI-MultiGPU.git
# %cd /kaggle/working/ComfyUI/custom_nodes/ComfyUI-MultiGPU
# !git pull
#!/kaggle/working/venv/bin/pip install --no-cache-dir -r requirements.txt
#Install ComfyUI-Impact-Pack
# %cd /kaggle/working/ComfyUI/custom_nodes
# !git clone https://github.com/ltdrdata/ComfyUI-Impact-Pack.git
# %cd /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Impact-Pack
# !git pull
# !/kaggle/working/venv/bin/pip install --no-cache-dir -r requirements.txt
#Install ComfyUI-Inspire-Pack
# %cd /kaggle/working/ComfyUI/custom_nodes
# !git clone https://github.com/ltdrdata/ComfyUI-Inspire-Pack.git
# %cd /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Inspire-Pack
# !git pull
# !/kaggle/working/venv/bin/pip install --no-cache-dir -r requirements.txt
#Install rgthree-comfy
# %cd /kaggle/working/ComfyUI/custom_nodes
# !git clone https://github.com/rgthree/rgthree-comfy.git
# %cd /kaggle/working/ComfyUI/custom_nodes/rgthree-comfy
# !git pull
# !/kaggle/working/venv/bin/pip install --no-cache-dir -r requirements.txt
#Install efficiency-nodes-comfyui
# %cd /kaggle/working/ComfyUI/custom_nodes
# !git clone https://github.com/jags111/efficiency-nodes-comfyui.git
# %cd /kaggle/working/ComfyUI/custom_nodes/efficiency-nodes-comfyui
# !git pull
# !/kaggle/working/venv/bin/pip install --no-cache-dir -r requirements.txt
#Install ComfyUI-WanStartEndFramesNative
# %cd /kaggle/working/ComfyUI/custom_nodes
# !git clone https://github.com/Flow-two/ComfyUI-WanStartEndFramesNative.git
# %cd /kaggle/working/ComfyUI/custom_nodes/ComfyUI-WanStartEndFramesNative
# !git pull
#!/kaggle/working/venv/bin/pip install --no-cache-dir -r requirements.txt
#Install cg-use-everywhere
# %cd /kaggle/working/ComfyUI/custom_nodes
# !git clone https://github.com/chrisgoringe/cg-use-everywhere.git
# %cd /kaggle/working/ComfyUI/custom_nodes/cg-use-everywhere
# !git pull
#!/kaggle/working/venv/bin/pip install --no-cache-dir -r requirements.txt
#Install ComfyUI-Unload-Model
# %cd /kaggle/working/ComfyUI/custom_nodes
# !git clone https://github.com/SeanScripts/ComfyUI-Unload-Model.git
# %cd /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Unload-Model
# !git pull
#!/kaggle/working/venv/bin/pip install --no-cache-dir -r requirements.txt
#Install ComfyUI-wanBlockswap
# %cd /kaggle/working/ComfyUI/custom_nodes
# !git clone https://github.com/orssorbit/ComfyUI-wanBlockswap.git
# %cd /kaggle/working/ComfyUI/custom_nodes/ComfyUI-wanBlockswap
# !git pull
#!/kaggle/working/venv/bin/pip install --no-cache-dir -r requirements.txt
#Install mikey_nodes
# %cd /kaggle/working/ComfyUI/custom_nodes
# !git clone https://github.com/bash-j/mikey_nodes.git
# %cd /kaggle/working/ComfyUI/custom_nodes/mikey_nodes
# !git pull
#!/kaggle/working/venv/bin/pip install --no-cache-dir -r requirements.txt
#Install kaytool
# %cd /kaggle/working/ComfyUI/custom_nodes
# !git clone https://github.com/kk8bit/kaytool.git
# %cd /kaggle/working/ComfyUI/custom_nodes/kaytool
# !git pull
# !/kaggle/working/venv/bin/pip install --no-cache-dir -r requirements.txt

#Install ComfyUI_IPAdapter_plus
# %cd /kaggle/working/ComfyUI/custom_nodes
# !git clone https://github.com/cubiq/ComfyUI_IPAdapter_plus.git
# %cd /kaggle/working/ComfyUI/custom_nodes/ComfyUI_IPAdapter_plus
# !git pull

#Install comfyui-various
# %cd /kaggle/working/ComfyUI/custom_nodes
# !git clone https://github.com/jamesWalker55/comfyui-various.git
# %cd /kaggle/working/ComfyUI/custom_nodes/comfyui-various
# !git pull

#Install ComfyUI_essentials
# %cd /kaggle/working/ComfyUI/custom_nodes
# !git clone https://github.com/cubiq/ComfyUI_essentials.git
# %cd /kaggle/working/ComfyUI/custom_nodes/ComfyUI_essentials
# !git pull
# !/kaggle/working/venv/bin/pip install --no-cache-dir -r requirements.txt

#Install ComfyUI_LayerStyle
# %cd /kaggle/working/ComfyUI/custom_nodes
# !git clone https://github.com/chflame163/ComfyUI_LayerStyle.git
# %cd /kaggle/working/ComfyUI/custom_nodes/ComfyUI_LayerStyle
# !git pull
# !/kaggle/working/venv/bin/pip install --no-cache-dir -r requirements.txt

#Install ComfyUI_Comfyroll_CustomNodes
# %cd /kaggle/working/ComfyUI/custom_nodes
# !git clone https://github.com/Suzie1/ComfyUI_Comfyroll_CustomNodes.git
# %cd /kaggle/working/ComfyUI/custom_nodes/ComfyUI_Comfyroll_CustomNodes
# !git pull

#Install ComfyUI-Easy-Use
# %cd /kaggle/working/ComfyUI/custom_nodes
# !git clone https://github.com/yolain/ComfyUI-Easy-Use.git
# %cd /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Easy-Use
# !git pull
# !/kaggle/working/venv/bin/pip install --no-cache-dir -r requirements.txt

#Install ComfyUI-Custom-Scripts
# %cd /kaggle/working/ComfyUI/custom_nodes
# !git clone https://github.com/pythongosssss/ComfyUI-Custom-Scripts.git
# %cd /kaggle/working/ComfyUI/custom_nodes/ComfyUI-Custom-Scripts
# !git pull
# !/kaggle/working/venv/bin/pip install --no-cache-dir -r requirements.txt

#Install 
#%cd /kaggle/working/ComfyUI/custom_nodes
#!wget https://gist.githubusercontent.com/city96/30743dfdfe129b331b5676a79c3a8a39/raw/ecb4f6f5202c20ea723186c93da308212ba04cfb/ComfyBootlegOffload.py
#Install ComfyUI-nunchaku
#%cd /kaggle/working/ComfyUI/custom_nodes
#!git clone https://github.com/mit-han-lab/ComfyUI-nunchaku.git
#%cd /kaggle/working/ComfyUI/custom_nodes/ComfyUI-nunchaku
#!git pull
#!/kaggle/working/venv/bin/pip install --no-cache-dir -r requirements.txt

# %%
# !chmod 777 /kaggle/working/* -R
# !add-apt-repository ppa:deadsnakes/ppa -y
# !apt update
# !apt dist-upgrade
# !apt autoremove
# !apt install python3.12 python3.12-venv
# !/usr/bin/python3.12 -m venv /kaggle/working/venv
# !source /kaggle/working/venv/bin/activate
# !/kaggle/working/venv/bin/python -m pip install --upgrade pip


# !ln -sf /kaggle/input/wan2.2_t2v_14b_vace-q4_k_m/gguf/default/1/Wan2.2_T2V_High_Noise_14B_VACE-Q4_K_M.gguf /kaggle/working/ComfyUI/models/unet/Wan2.2_T2V_High_Noise_14B_VACE-Q4_K_M.gguf
# !ls -lha /kaggle/working/ComfyUI/models/unet/Wan2.2_T2V_High_Noise_14B_VACE-Q4_K_M.gguf

# !ln -sf /kaggle/input/wan2.2_t2v_14b_vace-q4_k_m/gguf/default/1/Wan2.2_T2V_Low_Noise_14B_VACE-Q4_K_M.gguf /kaggle/working/ComfyUI/models/unet/Wan2.2_T2V_Low_Noise_14B_VACE-Q4_K_M.gguf
# !ls -lha /kaggle/working/ComfyUI/models/unet/Wan2.2_T2V_Low_Noise_14B_VACE-Q4_K_M.gguf

# !ln -sf /kaggle/input/wan2.2-i2v-a14b-gguf/gguf/default/1/Wan2.2-I2V-A14B-HighNoise-Q4_K_S.gguf /kaggle/working/ComfyUI/models/unet/Wan2.2-I2V-A14B-HighNoise-Q4_K_S.gguf
# !ls -lha /kaggle/working/ComfyUI/models/unet/Wan2.2-I2V-A14B-HighNoise-Q4_K_S.gguf

# !ln -sf /kaggle/input/wan2.2-i2v-a14b-gguf/gguf/default/1/Wan2.2-I2V-A14B-LowNoise-Q4_K_S.gguf /kaggle/working/ComfyUI/models/unet/Wan2.2-I2V-A14B-LowNoise-Q4_K_S.gguf
# !ls -lha /kaggle/working/ComfyUI/models/unet/Wan2.2-I2V-A14B-LowNoise-Q4_K_S.gguf

# !ln -sf /kaggle/input/wan2.2-i2v-a14b-gguf/gguf/default/1/Wan2.1_VAE.safetensors /kaggle/working/ComfyUI/models/vae/Wan2.1_VAE.safetensors
# !ls -lha /kaggle/working/ComfyUI/models/vae/Wan2.1_VAE.safetensors

# !ln -sf /kaggle/input/wan2.2-t2v-a14b-gguf/gguf/default/1/Wan2.2-T2V-A14B-LowNoise-Q4_K_S.gguf /kaggle/working/ComfyUI/models/unet/Wan2.2-T2V-A14B-LowNoise-Q4_K_S.gguf
# !ls -lha /kaggle/working/ComfyUI/models/unet/Wan2.2-T2V-A14B-LowNoise-Q4_K_S.gguf

# !ln -sf /kaggle/input/wan2.2-t2v-a14b-gguf/gguf/default/1/Wan2.2-T2V-A14B-HighNoise-Q4_K_S.gguf /kaggle/working/ComfyUI/models/unet/Wan2.2-T2V-A14B-HighNoise-Q4_K_S.gguf
# !ls -lha /kaggle/working/ComfyUI/models/unet/Wan2.2-T2V-A14B-HighNoise-Q4_K_S.gguf

# !ln -sf /kaggle/input/wan2.2-ti2v-5b-gguf/gguf/default/1/Wan2.2-TI2V-5B-Q8_0.gguf /kaggle/working/ComfyUI/models/unet/Wan2.2-TI2V-5B-Q8_0.gguf
# !ls -lha /kaggle/working/ComfyUI/models/unet/Wan2.2-TI2V-5B-Q8_0.gguf

# !ln -sf /kaggle/input/wan2.2-ti2v-5b-gguf/gguf/default/1/Wan2.2_VAE.safetensors /kaggle/working/ComfyUI/models/vae/Wan2.2_VAE.safetensors
# !ls -lha /kaggle/working/ComfyUI/models/vae/Wan2.2_VAE.safetensors

# !ln -sf /kaggle/input/umt5-xxl-encoder-q8_0/gguf/default/1/umt5-xxl-encoder-Q8_0.gguf /kaggle/working/ComfyUI/models/text_encoders/umt5-xxl-encoder-Q8_0.gguf
# !ls -lha /kaggle/working/ComfyUI/models/text_encoders/umt5-xxl-encoder-Q8_0.gguf

# !ln -sf /kaggle/input/umt5_xxl_fp16/other/default/1/umt5_xxl_fp16.safetensors  /kaggle/working/ComfyUI/models/text_encoders/umt5_xxl_fp16.safetensors
# !ls -lah /kaggle/input/umt5_xxl_fp16/other/default/1/umt5_xxl_fp16.safetensors

# !ln -sf /kaggle/input/umt5_xxl_fp8_e4m3fn_scaled/other/default/1/umt5_xxl_fp8_e4m3fn_scaled.safetensors /kaggle/working/ComfyUI/models/text_encoders/umt5_xxl_fp8_e4m3fn_scaled.safetensors
# !ls -lha /kaggle/working/ComfyUI/models/text_encoders/umt5_xxl_fp8_e4m3fn_scaled.safetensors

# !ln -sf /kaggle/input/umt5-xxl-encoder-q8_0/gguf/default/1/umt5-xxl-encoder-Q8_0.gguf /kaggle/working/ComfyUI/models/text_encoders/umt5-xxl-encoder-Q8_0.gguf
# !ls -lha /kaggle/working/ComfyUI/models/text_encoders/umt5-xxl-encoder-Q8_0.gguf

# !ln -sf /kaggle/input/lightx2v_cfg_step_distill_lora_rank64/tensorflow2/default/1/Wan21_I2V_14B_lightx2v_cfg_step_distill_lora_rank64.safetensors /kaggle/working/ComfyUI/models/loras/Wan21_I2V_14B_lightx2v_cfg_step_distill_lora_rank64.safetensors
# !ls -lha /kaggle/working/ComfyUI/models/loras/Wan21_I2V_14B_lightx2v_cfg_step_distill_lora_rank64.safetensors

# !ln -sf /kaggle/input/fastwan_t2v_14b_480p_lora_rank_128_bf16/tensorflow2/default/1/FastWan_T2V_14B_480p_lora_rank_128_bf16.safetensors /kaggle/working/ComfyUI/models/loras/FastWan_T2V_14B_480p_lora_rank_128_bf16.safetensors
# !ls -lha /kaggle/working/ComfyUI/models/loras/FastWan_T2V_14B_480p_lora_rank_128_bf16.safetensors

# !ln -sf /kaggle/input/clip_vision_h/tensorflow2/default/1/clip_vision_h.safetensors /kaggle/working/ComfyUI/models/clip_vision/clip_vision_h.safetensors
# !ls -lha /kaggle/working/ComfyUI/models/clip_vision/clip_vision_h.safetensors


#!ln -sf /kaggle/input/vae_flux_black_forest/other/default/1/vae_flux_black_forest.safetensors /kaggle/working/ComfyUI/models/vae/vae_flux_black_forest.safetensors
#!ls -lha /kaggle/working/ComfyUI/models/vae/vae_flux_black_forest.safetensors

#!ln -sf /kaggle/input/jibmixflux_v8accentueightnow.gguf/gguf/the-v8-pruned-model-bf16-11.84-gb/1/jibMixFlux_v8AccentueightNow.gguf /kaggle/working/ComfyUI/models/unet/jibMixFlux_v8AccentueightNow.gguf
#!ls -lha /kaggle/working/ComfyUI/models/unet/jibMixFlux_v8AccentueightNow.gguf

#!ln -sf /kaggle/input/t5-v1_1-xxl-encoder-q8_0/gguf/default/1/t5-v1_1-xxl-encoder-Q8_0.gguf /kaggle/working/ComfyUI/models/text_encoders/t5-v1_1-xxl-encoder-Q8_0.gguf
#!ls -lha /kaggle/working/ComfyUI/models/text_encoders/t5-v1_1-xxl-encoder-Q8_0.gguf

#!ln -sf /kaggle/input/clip_l/other/default/1/clip_l.safetensors /kaggle/working/ComfyUI/models/text_encoders/clip_l.safetensors
#!ls -lha /kaggle/working/ComfyUI/models/text_encoders/clip_l.safetensors

#!ln -sf /kaggle/input/wan2.1_t2v_14b_fusionx_vace-q8_0/gguf/default/1/Wan2.1_T2V_14B_FusionX_VACE-Q8_0.gguf /kaggle/working/ComfyUI/models/unet/Wan2.1_T2V_14B_FusionX_VACE-Q8_0.gguf
#!ls -lha /kaggle/working/ComfyUI/models/unet/Wan2.1_T2V_14B_FusionX_VACE-Q8_0.gguf

#!ln -sf /kaggle/input/vae_wan21/other/default/1/wan_2.1_vae.safetensors /kaggle/working/ComfyUI/models/vae/wan_2.1_vae.safetensors
#!ls -lha /kaggle/working/ComfyUI/models/vae/wan_2.1_vae.safetensors

#!ln -sf /kaggle/input/wan2.1_t2v_14b_fusionx_vace-q4_k_s/gguf/default/1/Wan2.1_T2V_14B_FusionX_VACE-Q4_K_S.gguf /kaggle/working/ComfyUI/models/unet/Wan2.1_T2V_14B_FusionX_VACE-Q4_K_S.gguf
#!ls -lha /kaggle/input/wan2.1_t2v_14b_fusionx_vace-q4_k_s/gguf/default/1/Wan2.1_T2V_14B_FusionX_VACE-Q4_K_S.gguf

# %%
# !chmod 777 /kaggle/working/* -R
# %cd /kaggle/working/
# !source /kaggle/working/venv/bin/activate
# !ssh -o StrictHostKeyChecking=no -i /kaggle/input/tunkey/tun.key -p 8844 -f -T -N -R 8888:localhost:8889 tun@164.152.50.65
#--cache-none --use-sage-attention
# !/kaggle/working/venv/bin/python3.12 /kaggle/working/ComfyUI/main.py --cache-none --listen 0.0.0.0 --port 8889
